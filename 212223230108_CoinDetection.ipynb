# %% [markdown]
# # Coin Detection using Morphological Operations and Thresholding
#
# #### Name: Krishna Prasad S
# #### Reg. No: 212223230108
# #### Slot 4E6-1

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Read image
img = cv2.imread("Coins.png")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.title("Orginal Image")
plt.imshow(img_rgb)
plt.show()

# %%
imageCopy = image.copy()
plt.imshow(image[:,:,::-1]);
plt.title("Original Image")
plt.show()
# Expected output

# %% [markdown]
# # Convert Image to Grayscale¶

# %%
# Convert image to grayscale
gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)

plt.figure(figsize=(12,12))
plt.subplot(121);plt.imshow(img_rgb);plt.title("Original Image")
plt.subplot(122); plt.imshow(gray,cmap='gray');plt.title("Grayscale Image"); plt.show()

# %%
plt.figure(figsize=(12,12))
plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(122); plt.imshow(imageGray,cmap='gray');plt.title("Grayscale Image"); plt.show()
# Expected output

# %% [markdown]
# # Split Image into R,G,B Channels

# %%
# Split cell into channels
# Store them in variables imageB, imageG, imageR
imageR, imageG, imageB = cv2.split(img_rgb)

plt.figure(figsize=(20,12))
plt.subplot(141);plt.imshow(img_rgb);plt.title("Original Image")
plt.subplot(142);plt.imshow(imageB,cmap='gray');plt.title("Blue Channel")
plt.subplot(143);plt.imshow(imageG,cmap='gray');plt.title("Green Channel")
plt.subplot(144);plt.imshow(imageR,cmap='gray');plt.title("Red Channel");
plt.show()

# %%
plt.figure(figsize=(20,12))
plt.subplot(141);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(142);plt.imshow(imageB,cmap='gray');plt.title("Blue Channel")
plt.subplot(143);plt.imshow(imageG,cmap='gray');plt.title("Green Channel")
plt.subplot(144);plt.imshow(imageR,cmap='gray');plt.title("Red Channel");
plt.show()
# Expected output

# %% [markdown]
# # Perform Thresholding

# %%
ret, thresh = cv2.threshold(imageG, 20, 255, cv2.THRESH_BINARY_INV)
plt.title("Threshold")
plt.imshow(thresh, cmap = 'gray')
plt.show()

# %%
# Expected output

# %% [markdown]
# # Perform morphological operations

# %%
kernal = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5,5))

dil = cv2.dilate(thresh,kernal,iterations=2)
plt.imshow(dil, cmap = 'gray')
plt.title("Dilated Image Iteration 2")
plt.show()

# %%
###
### YOUR CODE HERE
###
plt.imshow(imageDilated2,cmap='gray');plt.title('Dilated Image Iteration 2');plt.show()
# Expected output

# %%
# Display all the images
# you have obtained in the intermediate steps
###
### YOUR CODE HERE
###

# %%
# Get structuring element/kernel which will be used for dilation 
kernal = np.ones((2, 2))
ero = cv2.erode(dil, kernal,iterations=5)
plt.imshow(ero, cmap = 'gray')
plt.title("Eroded Image ")
plt.show()

# %%
###
### YOUR CODE HERE
###
plt.imshow(imageEroded,cmap='gray');plt.title("Eroded Image");plt.show()
# Expected output

# %%
###
### YOUR CODE HERE
###

# %% [markdown]
# #  Create SimpleBlobDetector

# %%
# Set up the SimpleBlobdetector with default parameters.
params = cv2.SimpleBlobDetector_Params()

params.blobColor = 0

params.minDistBetweenBlobs = 2

# Filter by Area.
params.filterByArea = False

# Filter by Circularity
params.filterByCircularity = True
params.minCircularity = 0.8

# Filter by Convexity
params.filterByConvexity = True
params.minConvexity = 0.8

# Filter by Inertia
params.filterByInertia =True
params.minInertiaRatio = 0.8

# %%
# Create SimpleBlobDetector
detector = cv2.SimpleBlobDetector_create(params)

# %% [markdown]
# # Detect Coins

# %%
# Detect blobs
###
### YOUR CODE HERE
###
keypoints = detector.detect(ero)
print(f"Number of coins detected: {len(keypoints)}")
# Out:
# Number of coins detected: 9

# %%
# Print number of coins detected
###
### YOUR CODE HERE
###
print(f"Number of coins detected: {len(keypoints)}")
# Out:
# Number of coins detected: 9

# %%
for k in keypoints:
    x, y = k.pt
    x = int(round(x))
    y = int(round(y))
    image1 = cv2.circle(img_rgb, (x, y), 5, (255, 255, 255), -1)
    d = k.size/2
    r = int(round(d))
    image2 = cv2.circle(image1, (x, y), r, (255, 255, 255), 2)

# %%
plt.imshow(image2)
plt.show()
